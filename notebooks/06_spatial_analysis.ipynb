# %% [markdown]
# # Day 6: 공간 분석 (간소화)
#
# **날짜**: 2025-07-09
#
# **목표**:
# - GeoJSON 미확보로 Choropleth 생략
# - 대신 자치구별 히트맵 스타일 시각화
# - 지역 그룹 분석

# %%
import sys
import os
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from utils import *

set_korean_font()
set_plot_style()

df = pd.read_csv(os.path.join(DATA_PATHS['processed'], 'integrated_data.csv'), encoding='utf-8-sig')
print(f"✅ Day 6: 공간 분석 (간소화)")

# %% [markdown]
# ## 1. 자치구별 히트맵 시각화

# %%
# CCTV 밀도와 범죄율을 히트맵으로 표현
heatmap_data = df[['자치구', '인구당_총CCTV', '인구당_CCTV효과범죄율']].set_index('자치구')
heatmap_data_normalized = (heatmap_data - heatmap_data.mean()) / heatmap_data.std()

fig, ax = plt.subplots(figsize=(6, 12))
sns.heatmap(heatmap_data_normalized, annot=False, cmap='RdYlGn_r', 
            center=0, linewidths=0.5, cbar_kws={'label': '표준화 값'})
ax.set_title('자치구별 CCTV 밀도 vs 범죄율 (표준화)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(DATA_PATHS['figures'], 'day6_district_heatmap.png'), dpi=300)
plt.show()

print("ℹ️ GeoJSON 미확보로 Choropleth 지도는 생략")
print("   실제 데이터 확보 시 geopandas로 지도 시각화 추가 가능")

# %%
print("✅ Day 6 완료")
